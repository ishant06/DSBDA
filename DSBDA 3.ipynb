# %%
import numpy as np 
import pandas as pd

# %%
data=pd.read_csv('../input/student-feedback-survey-responses/student_feedback.csv')

# %%
data

# %%
data.mean()

# %%
data.median()

# %%
data.median(axis=1)[0:4]

# %%
data.mode()

# %%
data.loc[:, 'Student ID'].mode()

# %%
data.min()

# %%
data.loc[:,'Student ID'].min(skipna=False)

# %%
data.max()

# %%
data.loc[:,'Student ID'].max(skipna=False)

# %%
data.std()

# %%
data.loc[:,'Student ID'].std()

# %%
data.std(axis=1)[0:4]

# %%
data.groupby(['Student ID'])['Use of presentations'].mean()

# %%
data_u=data.rename(columns={'Use of presentations':'Representation'},inplace=False)

# %%
data_u.groupby(['Student ID']).Representation.mean()

# %%
from sklearn import preprocessing
enc=preprocessing.OneHotEncoder()
enc_data=pd.DataFrame(enc.fit_transform([['Student ID']]).toarray())
enc_data

# %%
data_encode=data_u.join(enc_data)
data_encode

# %%
import numpy as mp
import pandas as pd

# %%
col_names=['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Species']

# %%
iris=pd.read_csv('../input/iris-data/iris.data', names=col_names)

# %%
irisSet=(iris['Species']=='Iris-setosa')

# %%
print('Iris-setosa')

# %%
print(iris[irisSet].describe())

# %%
irisVer=(iris['Species']=='Iris-versicolor')

# %%
print('Iris-versicolor')

# %%
print(iris[irisVer].describe())

# %%
irisVir=(iris['Species']=='Iris-virginica')

# %%
print('Iris-virginica')

# %%
print(iris[irisVir].describe())
